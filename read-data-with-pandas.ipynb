# %% [markdown]
# # 1.Read CSV File

# %%
import pandas as pd
df = pd.read_csv("california_cities.csv")
df.head(10)
# Out:
#    Unnamed: 0            city       latd       longd  elevation_m  \
# 0           0        Adelanto  34.576111 -117.432778        875.0
# 1           1     AgouraHills  34.153333 -118.761667        281.0
# 2           2         Alameda  37.756111 -122.274444          NaN
# 3           3          Albany  37.886944 -122.297778          NaN
# 4           4        Alhambra  34.081944 -118.135000        150.0
# 5           5      AlisoViejo  33.575000 -117.725556        127.0
# 6           6         Alturas  41.487222 -120.542500       1332.0
# 7           7      AmadorCity  38.419444 -120.824167        280.0
# 8           8  AmericanCanyon  38.168056 -122.252500         14.0
# 9           9         Anaheim  33.836111 -117.889722         48.0
#
#    elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0        2871.0             31765            56.027           56.009
# 1         922.0             20330             7.822            7.793
# ...

# %%
#Add Header
df2 = pd.read_csv("california_cities.csv", header = None, names = ['ID', 'first_name', 'salary'])
df2.head()
# Out:
#                                                                                                                                                                                        ID  \
# NaN   city        latd               longd               elevation_m elevation_ft population_total area_total_sq_mi area_land_sq_mi    area_water_sq_mi     area_total_km2  area_land_km2
# 0.0   Adelanto    34.57611111111112  -117.43277777777779 875.0       2871.0       31765            56.027           56.00899999999999  0.018000000000000002 145.107               145.062
# 1.0   AgouraHills 34.15333333333333  -118.76166666666667 281.0       922.0        20330            7.822            7.792999999999999  0.028999999999999998 20.26                  20.184
# 2.0   Alameda     37.75611111111111  -122.27444444444444 NaN         33.0         75467            22.96            10.610999999999999 12.349               59.465                 27.482
# ...

# %% [markdown]
# # 2. Read file from link

# %%
df3 = pd.read_csv("http://winterolympicsmedals.com/medals.csv")
df3
# Out:
#       Year      City       Sport       Discipline  NOC                  Event  \
# 0     1924  Chamonix     Skating   Figure skating  AUT             individual
# 1     1924  Chamonix     Skating   Figure skating  AUT             individual
# 2     1924  Chamonix     Skating   Figure skating  AUT                  pairs
# 3     1924  Chamonix   Bobsleigh        Bobsleigh  BEL               four-man
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN             ice hockey
# 5     1924  Chamonix    Biathlon         Biathlon  FIN        military patrol
# 6     1924  Chamonix     Skating   Figure skating  FIN                  pairs
# 7     1924  Chamonix     Skating    Speed skating  FIN                 10000m
# 8     1924  Chamonix     Skating    Speed skating  FIN                 10000m
# 9     1924  Chamonix     Skating    Speed skating  FIN                  1500m
# 10    1924  Chamonix     Skating    Speed skating  FIN                  5000m
# ...

# %% [markdown]
# # 3. Read Txt file

# %%
df4 = pd.read_table("adult_income_data.txt")
df5 = pd.read_csv("example2.txt", sep ="\t") # sep= "\s+ " and sep= "," and sep = "-"

# %% [markdown]
# # 4. Read excel file

# %%
df6 = pd.read_excel("dataset-customer-satisfaction-survey-results-agencies.xls",sheetname="Agency Survey Results 2012")
